# %%
import pandas as pd

# %%
df['MFtr'].unique()
# Out:
# array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])

# %%
(df['MFtr'].value_counts())
# Out:
# MFtr
# 0.05    383800
# 0.10    383800
# 0.15    383800
# 0.20    383800
# 0.25    383800
# 0.30    383800
# 0.35    383800
# 0.40    383800
# 0.45    383800
# 0.50    383800
# 0.55    383800
# 0.60    383800
# 0.65    383800
# 0.70    383800
# 0.75    383800
# 0.80    383800
# 0.85    383800
# 0.90    383800
# 0.95    383800
# Name: count, dtype: int64

# %%
df = pd.read_csv('results_syn.csv')
df.head()
# Out:
#    MFtr  MFte  R_1  P_1   AE Distance        Qnt
# 0  0.05  0.05  0.0  0.0  0.0      NaN         CC
# 1  0.05  0.05  0.0  0.0  0.0      NaN        ACC
# 2  0.05  0.05  0.0  0.0  0.0   topsoe  ACCSyn-TS
# 3  0.05  0.05  0.0  0.0  0.0      NaN        T50
# 4  0.05  0.05  0.0  0.0  0.0   topsoe  T50Syn-TS
