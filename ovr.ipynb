# %%
import pandas as pd
import mlquantify as ml

# %%
import pandas as pd
import mlquantify as ml

from mlquantify.model_selection._protocol import UPP

df = pd.read_csv("./datasets/Dermatology.csv")
df.head(3)

upp = UPP(batch_size=100, n_prevalences=2, random_state=42, repeats=1)

X = df.drop(columns=['class'])
y = df['class']

for idx in upp.split(X, y):
    selected_df = df.iloc[idx]
selected_df['class'].value_counts(normalize=True)
selected_df
# Out:
#         erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 829355         1        1                 2        2                   0
# 723070         2        2                 0        1                   0
# 930081         2        3                 2        3                   0
# 807932         2        2                 2        1                   0
# 268368         2        2                 2        0                   0
# ...          ...      ...               ...      ...                 ...
# 523284         1        1                 1        3                   0
# 393560         3        2                 2        0                   0
# 2250           3        2                 1        2                   3
# 325311         2        1                 0        2                   1
# 416832         2        2                 1        1                   0
#
#         polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 829355                  0                   0                         0
# 723070                  0                   2                         0
# 930081                  0                   0                         0
# 807932                  0                   0                         0
# 268368                  0                   0                         0
# ...                   ...                 ...                       ...
# 523284                  0                   0                         0
# 393560                  0                   0                         0
# 2250                    0                   0                         0
# 325311                  0                   0                         0
# 416832                  0                   0                         0
#
#         knee_and_elbow_involvement  scalp_involvement  ...  \
# 829355                           0                  0  ...
# 723070                           1                  0  ...
# 930081                           2                  0  ...
# 807932                           3                  2  ...
# 268368                           0                  1  ...
# ...                            ...                ...  ...
# 523284                           0                  0  ...
# 393560                           2                  0  ...
# 2250                             2                  1  ...
# 325311                           0                  0  ...
# 416832                           0                  0  ...
#
#         disappearance_of_the_granular_layer  \
# 829355                                    0
# 723070                                    0
# 930081                                    2
# 807932                                    3
# 268368                                    0
# ...                                     ...
# 523284                                    0
# 393560                                    2
# 2250                                      0
# 325311                                    1
# 416832                                    2
#
#         vacuolisation_and_damage_of_basal_layer  spongiosis  \
# 829355                                        0           0
# 723070                                        0           2
# 930081                                        0           0
# 807932                                        0           0
# 268368                                        0           0
# ...                                         ...         ...
# 523284                                        0           3
# 393560                                        0           0
# 2250                                          0           0
# 325311                                        0           2
# 416832                                        0           0
#
#         saw-tooth_appearance_of_retes  follicular_horn_plug  \
# 829355                              2                     0
# 723070                              0                     3
# 930081                              0                     0
# 807932                              0                     0
# 268368                              0                     0
# ...                               ...                   ...
# 523284                              0                     0
# 393560                              0                     0
# 2250                                0                     0
# 325311                              0                     0
# 416832                              0                     0
#
#         perifollicular_parakeratosis  inflammatory_monoluclear_inflitrate  \
# 829355                             0                                    1
# 723070                             3                                    1
# 930081                             0                                    2
# 807932                             0                                    2
# 268368                             0                                    2
# ...                              ...                                  ...
# 523284                             0                                    2
# 393560                             0                                    2
# 2250                               0                                    2
# 325311                             0                                    2
# 416832                             0                                    2
#
#         band-like_infiltrate        Age  class
# 829355                     0  37.167371      5
# 723070                     0  22.384532      6
# 930081                     0   5.190035      1
# 807932                     0  57.568806      1
# 268368                     1  17.399272      1
# ...                      ...        ...    ...
# 523284                     0  12.508168      5
# 393560                     0  17.370999      1
# 2250                       0  37.881907      1
# 325311                     0  41.877359      4
# 416832                     0  28.569507      1
#
# [100 rows x 35 columns]

# %%
df['class'].value_counts(normalize=True)
# Out:
# class
# 1    0.304589
# 3    0.196592
# 2    0.165951
# 5    0.142642
# 4    0.134533
# 6    0.055693
# Name: proportion, dtype: float64

# %%
selected_df['class'].value_counts(normalize=True)
# Out:
# class
# 4    0.28
# 1    0.23
# 6    0.20
# 2    0.16
# 5    0.07
# 3    0.06
# Name: proportion, dtype: float64

# %%
upp = UPP(batch_size=100, n_prevalences=2, random_state=42, repeats=2)

X = df.drop(columns=['game'])
y = df['game']

for idx in upp.split(X, y):
    print(y.iloc[idx])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 upp = UPP(batch_size=100, n_prevalences=2, random_state=42, repeats=2)
# ----> 3 X = df.drop(columns=['game'])
#       4 y = df['game']
#       6 for idx in upp.split(X, y):
#
# File c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['game'] not found in axis"
