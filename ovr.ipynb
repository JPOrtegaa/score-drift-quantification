# %%
import pandas as pd
import mlquantify as ml

# %%
import pandas as pd
import mlquantify as ml

from mlquantify.model_selection._protocol import UPP

df = pd.read_csv("./datasets/Chess game.csv")
df.head(3)

upp = UPP(batch_size=100, n_prevalences=5, random_state=42, repeats=1)

X = df.drop(columns=['game'])
y = df['game']

for idx in upp.split(X, y):
    print(y.iloc[idx])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39796\3625334247.py in ?()
#      10
#      11 X = df.drop(columns=['game'])
#      12 y = df['game']
#      13
# ---> 14 for idx in upp.split(X, y):
#      15     print(y.iloc[idx])
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\mlquantify\model_selection\_protocol.py in ?(self, X, y)
#      90         ------
#      91         Generator[np.ndarray, np.ndarray]
#      92             A generator that yields the indices for each split.
#      93         """
# ---> 94         X, y = validate_data(self, X, y)
#      95         for idx in self._iter_indices(X, y):
#      96             if len(idx) > len(X):
#      97                 warning(f"Batch size {len(idx)} exceeds dataset size {len(X)}. Replacement sampling will be used.")
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\mlquantify\utils\_validation.py in ?(quantifier, X, y, reset, validate_separately, skip_check_array, **check_params)
#     290             if "estimator" not in check_y_params:
#     291                 check_y_params = {**default_check_params, **check_y_params}
#     292             y = check_array(y, input_name="y", **check_y_params)
#     293         else:
# --> 294             X, y = check_X_y(X, y, **check_params)
#     295         out = X, y
#     296
#     297     return out
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366         )
#    1367
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#    1373         accept_large_sparse=accept_large_sparse,
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'a'

# %%
df.drop(columns=['V11'])
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0      0.266074 -0.165620  0.320980  0.483299  0.172340  0.273364  0.371178
# 1      0.130292  0.870736 -3.210528  0.062493  0.261718  1.436060  1.465940
# 2     -0.116585  0.069915  0.068476 -0.783147  0.261718  0.439463 -0.081827
# 3      0.031541  0.297600 -3.210528 -0.583590 -0.721442 -0.307984  0.710932
# 4      0.229043  0.807926 -0.052442  0.082634  0.261718  0.148790  0.635431
# ...         ...       ...       ...       ...       ...       ...       ...
# 20862 -0.128929 -0.040001  0.057807  0.557894  0.261718 -0.930856 -0.044076
# 20863  0.266074  0.556689 -0.020434  0.176624  0.261718 -0.515608  0.597681
# 20864 -0.054866  0.580242  0.032912 -0.016668  0.261718  1.519109  0.371178
# 20865  0.080916  0.588093  0.015130  0.002250  0.261718 -0.930856 -0.270579
# 20866  0.377169  0.014957  0.381439  0.292753  0.261718 -1.470679 -0.006326
#
#              V8        V9       V10
# 0      0.929823  0.251173  0.159345
# 1      0.636203  0.282354  0.515587
# 2     -0.888236 -0.123005  0.582939
# 3      1.051693  0.594169 -0.533994
# 4      0.051062  0.032902 -0.086652
# ...         ...       ...       ...
# 20862  1.158458  2.277968 -0.699884
# 20863  0.178349  0.625350 -0.657245
# 20864 -0.985508 -0.403638  1.276301
# 20865  0.163807 -0.091823 -0.593329
# 20866 -0.494919 -0.247731 -1.212974
#
# [20867 rows x 10 columns]

# %%
X
# Out:
# array([['a', 1, 'b', 3, 'c', 2],
#        ['a', 1, 'c', 1, 'c', 2],
#        ['a', 1, 'c', 1, 'd', 1],
#        ...,
#        ['b', 1, 'g', 7, 'e', 7],
#        ['b', 1, 'g', 7, 'f', 5],
#        ['b', 1, 'g', 7, 'g', 5]], shape=(28056, 6), dtype=object)

# %%
y
# Out:
# array(['draw', 'draw', 'draw', ..., 'sixteen', 'sixteen', 'sixteen'],
#       shape=(28056,), dtype=object)

# %%
upp = UPP(batch_size=100, n_prevalences=5, random_state=42, repeats=1)

X = df.drop(columns=['game'])
y = df['game']

for idx in upp.split(X, y):
    print(y.iloc[idx])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39796\4267231153.py in ?()
#       2
#       3 X = df.drop(columns=['game'])
#       4 y = df['game']
#       5
# ----> 6 for idx in upp.split(X, y):
#       7     print(y.iloc[idx])
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\mlquantify\model_selection\_protocol.py in ?(self, X, y)
#      90         ------
#      91         Generator[np.ndarray, np.ndarray]
#      92             A generator that yields the indices for each split.
#      93         """
# ---> 94         X, y = validate_data(self, X, y)
#      95         for idx in self._iter_indices(X, y):
#      96             if len(idx) > len(X):
#      97                 warning(f"Batch size {len(idx)} exceeds dataset size {len(X)}. Replacement sampling will be used.")
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\mlquantify\utils\_validation.py in ?(quantifier, X, y, reset, validate_separately, skip_check_array, **check_params)
#     290             if "estimator" not in check_y_params:
#     291                 check_y_params = {**default_check_params, **check_y_params}
#     292             y = check_array(y, input_name="y", **check_y_params)
#     293         else:
# --> 294             X, y = check_X_y(X, y, **check_params)
#     295         out = X, y
#     296
#     297     return out
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366         )
#    1367
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#    1373         accept_large_sparse=accept_large_sparse,
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\2Mestrado\score-drift-quantification\venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'a'
